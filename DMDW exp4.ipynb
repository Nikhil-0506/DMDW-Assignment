# %%
import pandas as pd
import numpy as np
import warnings
import seaborn as sns

# %%
data=pd.read_csv("Student Data.csv")
data.describe()
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
import pandas as pd
import numpy as np
import warnings
import seaborn as sns
